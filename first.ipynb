# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
a = 10
b = 20
if a > b:
    print("a is greater than b")
else:
    print("b is greater than a")
# Out:
# b is greater than a

# %%
marks = 10 
carbon_footprint = 400.75
city = "Nagpur"
print(f"The carbon footprint of the city { city } is { carbon_footprint }  kgCO2e")
# Out:
# The carbon footprint of the city Nagpur is 400.75  kgCO2e

# %%
city = input("Enter the city name: ")
carbon_footprint = input("Enter the carbon footprint of the city: ")
print(f"The carbon footprint of the city { city } is { carbon_footprint }  kgCO2e")
